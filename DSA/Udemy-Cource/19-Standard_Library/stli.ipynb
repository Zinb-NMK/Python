# %% [markdown]
#  Python's standard Library is a vast collection of modules and packages that come bundled with python providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in python Standard Library

# %%
import array

arr = array.array('i', [1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import numpy as np

arr_np = np.array([1,2,3,4,5])
print(arr_np)
# Out:
# [1 2 3 4 5]

# %%
import random
print(random.randint(1,10))
# Out:
# 5

# %% [markdown]
#  File And Directory Access

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Manoj Kumar\OneDrive\Desktop\Python\Python\DSA\Udemy-Cource\19-Standard_Library

# %%
with open("test.py", "w") as file:
    pass

# %% [markdown]
# ## High level operations on files and collections of files

# %%
import shutil

# Copy the contents of source.txt to dest.txt
shutil.copyfile('source.txt', 'dest.txt')
# Out:
# 'dest.txt'

# %%
## Data Serialization

import json
data = {'name':'Ajay', 'age':30}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

past_data = json.loads(json_str)
print(past_data)
print(type(past_data))
# Out:
# {"name": "Ajay", "age": 30}
# <class 'str'>
# {'name': 'Ajay', 'age': 30}
# <class 'dict'>

# %%
## CSV

import csv

with open('data.csv', mode='w', newline='')as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Ajay', 30])


with open('data.csv', mode = 'r')as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Ajay', '30']
