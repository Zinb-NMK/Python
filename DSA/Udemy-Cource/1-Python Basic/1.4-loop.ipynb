# %%
for i in range(10):
    if i==6:
        break
    print(i)

# %%
for i in range(9):
    if i==4:
        continue
    print(i)

# %%
#pass
for i in range(5):
    if i==2:
        pass
    print(i)

# %%
for i in range(3):
    for j in range(2):
        print(f"i={i}, j={j}")
# Out:
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1

# %%
n = int(input("Enter a num: "))
count = 0
for i in range(n+1):
    count += i
print(count)
# Out:
# 15

# %%
n=int(input("enter N: "))
sum = 0
count = 1
while count <= n:
    sum+=count
    count +=1
print(sum)
# Out:
# 15

# %%
# prim btw 1 to n
for n in range(1,101):
    if n >1:
        for i in range(2,n):
            if n%i==0:
                break
        else:
            print(n)

# %%
n = int(input())
c = 0
while n !=0:
    c += 1
    n//=10
    print(n)
# Out:
# 678
# 67
# 6
# 0
