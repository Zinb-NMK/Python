# %% [markdown]
# Introduction

# %%
def list_input(lst1):
    ""
    
    return lst1
lst = list(map(int, input("Enter List elements: ").split()))
print(list_input(lst))
# Out:
# [23, 4, 56, 6]

# %%
import array as arr

arr = arr.array('i', [1,3,4,2,6])
print(arr)
arr[0] = 7
print(arr)
# Out:
# array('i', [1, 3, 4, 2, 6])
# array('i', [7, 3, 4, 2, 6])

# %% [markdown]
# Binary Search Can only be applied on Sorted Lists

# %%
def binary_search(sorted_list, target):
    """"""
    #
    start = 0
    end = len(sorted_list) - 1
    for i in range(len(sorted_list)):
        mid = (end - start) // 2

        if sorted_list[mid] == target:
            return mid
        elif sorted_list[mid] < target:
            start = mid + 1
        else:
            end = mid - 1 
    return -1
sorted_list = list(map(int, input("Enter Elements in increasing order(Sorted):").split()))
target = int(input("Enter target element: "))
print(binary_search(sorted_list, target))
# Out:
# 2
