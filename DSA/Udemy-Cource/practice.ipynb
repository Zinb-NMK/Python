# %%
def even(num):
    if num%2==0:
        return True

# %%
lst = [1,3,2,4,55,67,8,90,60,7,88]
list(filter(lambda x:x>25 and x%2==0,lst))
# Out:
# [90, 60, 88]

# %%
people = [
    {'name': 'nani', 'age':12},
    {'name': 'ma', 'age':52},
    {'name': 'na', 'age':82},
    {'name': 'ni', 'age':22}
]
def age_g_25(p):
    return p['age']>25

list(filter(age_g_25,people))
# Out:
# [{'name': 'ma', 'age': 52}, {'name': 'na', 'age': 82}]
