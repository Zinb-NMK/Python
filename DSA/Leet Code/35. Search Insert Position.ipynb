# %% [markdown]
# Given a sorted array of distinct integers and a target value, return the index if the target is found. If not, return the index where it would be if it were inserted in order.
#
# You must write an algorithm with O(log n) runtime complexity.
#
# Example 1:
# Input: nums = [1,3,5,6], target = 5
# Output: 2
#
# Example 2:
# Input: nums = [1,3,5,6], target = 2
# Output: 1
#
# Example 3:
# Input: nums = [1,3,5,6], target = 7
# Output: 4

# %%
def Insert_Position_Search(nums, target):
    #
    n = len(nums)
    start = 0
    end = n - 1
    while(start <= end):
        mid = (start + end) // 2
        if nums[mid] == target:
            return mid
        elif target > nums[mid]:
            start = mid+1
        elif target < nums[mid]:
            end = mid - 1
    return start
target = int(input("Enter the target number: "))
nums = list(map(int, input("Enter the Assending list Elements: ").split()))
print(Insert_Position_Search(nums, target))
# Out:
# 3

# %% [markdown]
# Example 1:
# Input: nums = [1,3,5,6], target = 5
# Output: 2
#
# Example 2:
# Input: nums = [1,3,5,6], target = 2
# Output: 1
#
# Example 3:
# Input: nums = [1,3,5,6], target = 7
# Output: 4

# %%
def insert_val(nums, target):
    #
    start = 0
    end = len(nums)-1

    while(start<=end):
        mid = (start + end) // 2

        if nums[mid] == target:
            return mid
        elif nums[mid] > target:
            end = mid - 1
        elif nums[mid] < target:
            start = mid + 1
    return start

nums = list(map(int, input("Enter the Assending list Elements: ").split()))
target = int(input("Enter the target number: "))
print(insert_val(nums, target))
# Out:
# 1
