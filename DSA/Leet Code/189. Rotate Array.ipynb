# %% [markdown]
# Given an integer array nums, rotate the array to the right by k steps, where k is non-negative.
#
# Example 1:
# Input: nums = [1,2,3,4,5,6,7], k = 3
# Output: [5,6,7,1,2,3,4]
# Explanation:
# rotate 1 steps to the right: [7,1,2,3,4,5,6]
# rotate 2 steps to the right: [6,7,1,2,3,4,5]
# rotate 3 steps to the right: [5,6,7,1,2,3,4]
#
# Example 2:
# Input: nums = [-1,-100,3,99], k = 2
# Output: [3,99,-1,-100]
# Explanation:
# rotate 1 steps to the right: [99,-1,-100,3]
# rotate 2 steps to the right: [3,99,-1,-100]

# %%
def reverse(arr, start, end):
    while start < end:
        arr[start], arr[end] = arr[end], arr[start]
        start += 1
        end -= 1

def right_rotate(arr, k):
    n = len(arr)
    k = k % n # Handles if k > len(arr)

    reverse(arr, 0 , n-1) # Step1 --> Whole arr Rotation
    reverse(arr, 0, k-1) # Step2 --> Rotate upto k - 1 (First Half)
    reverse(arr, k, n - 1) # Step3 --> Rotate 2nd Half of the array

    return arr

arr = list(map(int, input("Enter arr elements: " ).split()))
k = int(input("Enter Number of Rotations: "))
print(right_rotate(arr, k))
# Out:
# [4, 5, 1, 2, 3]
