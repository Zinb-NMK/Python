# %% [markdown]
# ATM Meachine

# %%
class atm_meachine:
    def __init__(self):
        self.balance = 0
        self.pin = ""
        self.menu()

    
    def menu(self):
        user_input = int(input("""Enter 1. Create PIN, 
        2. Check Balance, 3. Update PIN: , 
        4. Withdraw, 5. Deposit: , 
        any other num to exit():"""))

        if user_input == 1:
            # Create Pin
            self.create_pin()
        elif user_input== 2:
            # Check Balance
            self.check_balance()
        elif user_input == 3:
            # Update Pin
            self.update_pin()
        elif user_input == 4:
            # Withdraw
            self.withdraw()
        elif user_input == 5:
            # Deposit
            self.deposit
        else:
            print("Thank you for using this ATM machine")
        

    def create_pin(self):
        user_pin = input("Create a pin: ")
        re_pin = input("Re-Enter your pin: ")
        if user_pin == re_pin:
            self.pin = user_pin
            print("Pin created successfully")
        else:
            print("Check your pin and try again")
        user_balance = int(input("Enter your balance: "))
        self.balance = user_balance
        self.menu()

        
    
    def check_balance(self):
        pin = input("Enter your pin: ")
        if pin == self.pin:
            print(f"Your balance is: {self.balance}")
        else:
            print("Check your pin and try again!")
        self.menu()

    def update_pin(self):
        old_pin = input("Enter your old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter your new pin: ")
            self.pin = new_pin
            print("Pin changed Successfully!")
        else:
            print("Check Your old pin and try again!")
        self.menu()
    
    def withdraw(self):
        pin = input("Enter your pin: ")
        if pin == self.pin:
            withdraw_amount = int(input("Enter amount to withdraw: "))
            if self.balance >= withdraw_amount:
                self.balance -= withdraw_amount
                print(f"Available amount is: {self.balance}")
            else:
                print("Insufficient balance!")
        else:
            print("check your pin and try again!")
        self.menu()
    
    def deposit(self):
        pin = input("Enter your pin: ")
        if pin == self.pin:
            deposit = int(input("Enter anount to be deposited: "))
            if deposit > 0:
                self.balance += deposit
                print(f"Available balance is {self.balance}")
            else:
                print("Deposit must be greater then -> 0! ")
        else:
            print("Check your pin and try again!")


obi = atm_meachine()

# %% [markdown]
# Magic Method / Dunder Methods in OOP

# %%
# __methodname__ --- It is concedered as magic method

class Temp:
    def __init__(self):
        print("Hello World")
obj = Temp()

# %% [markdown]
# Reference Vareable

# %%
class Person:
    def __init__(self):
        self.name = "Jocker"
p = Person()

# %%
print(p.name)

# %%
q = p

# %%
id(p)

# %%
id(q)

# %%
print(p.name)
print(q.name)

# %%
q.name = "lon"

# %%
print(q.name)
print(p.name)

# %% [markdown]
# Pass by reference in OOP

# %%
class Person:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

# Outside of the class

def greeting(person):
    print(f"Hi My name is {person.name} and i am a {person.gender}")
    return p1

# %%
p = Person("radha", "Female")

# %%
a = greeting(p)

# %%
a.name

# %%
p.gender

# %% [markdown]
# Instance Variable in OOPS

# %%
class Person:
    def __init__(self, name, country):
        self.name = name
        self.country = country

# %%
p1 = Person("mano", "ind")

# %%
p2 = Person("ajay", "Ind")

# %%
p3 = Person("tom", "Ind")

# %%
print(id(p1), id(p2), id(p3))

# %%
p1.name

# %%
p2.name

# %%
p3.name

# %% [markdown]
# OOPs ----> Encapsulation: Encapsulation is a fundamental OOP's Principle in python. It protects your class from accidental changes or deletions and promotes code reusability and maintainability

# %%
class atm:
    def __init__(self):
        self.balance = 0
        self.pin = ""
        #self.menu()


    def menu(self):
        user_input = int(input("""Enter 1. Create PIN,
        2. Check Balance, 3. Update PIN: ,
        4. Withdraw, 5. Deposit: ,
        any other num to exit():"""))

        if user_input == 1:
            # Create Pin
            self.create_pin()
        elif user_input== 2:
            # Check Balance
            self.check_balance()
        elif user_input == 3:
            # Update Pin
            self.update_pin()
        elif user_input == 4:
            # Withdraw
            self.withdraw()
        elif user_input == 5:
            # Deposit
            self.deposit
        else:
            print("Thank you for using this ATM machine")


    def create_pin(self):
        user_pin = input("Create a pin: ")
        re_pin = input("Re-Enter your pin: ")
        if user_pin == re_pin:
            self.pin = user_pin
            print("Pin created successfully")
        else:
            print("Check your pin and try again")
        user_balance = int(input("Enter your balance: "))
        self.balance = user_balance
        #self.menu()



    def check_balance(self):
        pin = input("Enter your pin: ")
        if pin == self.pin:
            print(f"Your balance is: {self.balance}")
        else:
            print("Check your pin and try again!")
        #self.menu()

    def update_pin(self):
        old_pin = input("Enter your old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter your new pin: ")
            self.pin = new_pin
            print("Pin changed Successfully!")
        else:
            print("Check Your old pin and try again!")
        #self.menu()

    def withdraw(self):
        pin = input("Enter your pin: ")
        if pin == self.pin:
            withdraw_amount = int(input("Enter amount to withdraw: "))
            if self.balance >= withdraw_amount:
                self.balance -= withdraw_amount
                print(f"Available amount is: {self.balance}")
            else:
                print("Insufficient balance!")
        else:
            print("check your pin and try again!")
        #self.menu()

    def deposit(self):
        pin = input("Enter your pin: ")

        if pin == self.pin:
            deposit = int(input("Enter anount to be deposited: "))
            if deposit > 0:
                self.balance += deposit
                print(f"Available balance is {self.balance}")
            else:
                print("Deposit must be greater then -> 0! ")
        else:
            print("Check your pin and try again!")


obj = atm()

# %%
obj.create_pin()

# %%
obj.check_balance()

# %%
obj.balance = "dfgh"

# %%
obj.check_balance()

# %%
obj.withdraw()

# %% [markdown]
# Private Var

# %%
class atm:
    def __init__(self):
        self.__balance = 0
        self.pin = ""
        #self.menu()


    def menu(self):
        user_input = int(input("""Enter 1. Create PIN,
        2. Check Balance, 3. Update PIN: ,
        4. Withdraw, 5. Deposit: ,
        any other num to exit():"""))

        if user_input == 1:
            # Create Pin
            self.create_pin()
        elif user_input== 2:
            # Check Balance
            self.check_balance()
        elif user_input == 3:
            # Update Pin
            self.update_pin()
        elif user_input == 4:
            # Withdraw
            self.withdraw()
        elif user_input == 5:
            # Deposit
            self.deposit
        else:
            print("Thank you for using this ATM machine")


    def create_pin(self):
        user_pin = input("Create a pin: ")
        re_pin = input("Re-Enter your pin: ")
        if user_pin == re_pin:
            self.pin = user_pin
            print("Pin created successfully")
        else:
            print("Check your pin and try again")
        user_balance = int(input("Enter your balance: "))
        self.__balance = user_balance
        #self.menu()



    def check_balance(self):
        pin = input("Enter your pin: ")
        if pin == self.pin:
            print(f"Your balance is: {self.__balance}")
        else:
            print("Check your pin and try again!")
        #self.menu()

    def update_pin(self):
        old_pin = input("Enter your old pin: ")
        if old_pin == self.pin:
            new_pin = input("Enter your new pin: ")
            self.pin = new_pin
            print("Pin changed Successfully!")
        else:
            print("Check Your old pin and try again!")
        #self.menu()

    def withdraw(self):
        pin = input("Enter your pin: ")
        if pin == self.pin:
            withdraw_amount = int(input("Enter amount to withdraw: "))
            if self.__balance >= withdraw_amount:
                self.__balance -= withdraw_amount
                print(f"Available amount is: {self.__balance}")
            else:
                print("Insufficient balance!")
        else:
            print("check your pin and try again!")
        #self.menu()

    def deposit(self):
        pin = input("Enter your pin: ")

        if pin == self.pin:
            deposit = int(input("Enter anount to be deposited: "))
            if deposit > 0:
                self.__balance += deposit
                print(f"Available balance is {self.__balance}")
            else:
                print("Deposit must be greater then -> 0! ")
        else:
            print("Check your pin and try again!")


obj = atm()

# %%
obj.create_pin()
# Out:
# Pin created successfully

# %%
obj.balance = "dfgh"

# %%
obj.check_balance()
# Out:
# Your balance is: 5000

# %%
obj.balance
# Out:
# 'dfgh'

# %%
obj._atm__balance
# Out:
# 5000

# %%
git status
# Out:
#   Cell In[1], line 1
#     git status
#         ^
# SyntaxError: invalid syntax
