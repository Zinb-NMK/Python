# %%
from random import choice
coin = choice(['head', 'tails'])
print(coin)
# Out:
# tails

# %%
import random
num = random.randint(1, 100)
print(num)
# Out:
# 15

# %%
import random

cards = ["jack", 'Queen', 'King']
random.shuffle(cards)
for card in cards:
    print(card)
# Out:
# King
# jack
# Queen

# %%
import statistics

print(statistics.mean([100, 90]))
# Out:
# 95

# %%
import sys

if len(sys.argv) < 2:
    sys.exit("Too few arguments: ")

for arg in sys.argv[1:]:
    print("hello, my name", arg)
# Out:
# hello, my name -f
# hello, my name C:\Users\Manoj Kumar\AppData\Roaming\jupyter\runtime\kernel-ded09980-d6ad-45b9-9263-860077ffc7cc.json
