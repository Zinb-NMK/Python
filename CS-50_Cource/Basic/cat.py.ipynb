# %%
from Tools.scripts.summarize_stats import name


def main():
    mew(10)

def mew(n):
    for _ in range(n):
        print("Meow")

main()

# %%
Students = [
    {"name": "Manoj", "house":"goa", "gender": "male"},
    {"name": "kumar", "house":"vizag", "gender": "male"},
    {"name": "jain", "house":"ap", "gender": "Female"},
    {"name": "siva", "house":"UP", "gender": "Female"}
]

for student in Students:
    print(student["name"], student['house'] ,sep=", ")
# Out:
# Manoj, goa
# kumar, vizag
# jain, ap
# siva, UP

# %%
for _ in range(3):
    print("#")
# Out:
# #
# #
# #

# %%
def main():
    print_col(3)

def print_col(height):
    for _ in range(height):
        print("#")

main()
# Out:
# #
# #
# #

# %%
def main():
    print_row(4)


def print_row(height):
    print("?"* height)

main()
# Out:
# ????

# %%
def main():
    print_sq(4)

def print_sq(size):

    # for each row in sq
    for i in range(size):

        #for each brick in row
        for j in range(size):

            # print row
            print("#", end="")
        print()

main()
# Out:
# ####
# ####
# ####
# ####
